# %%
import os
import sys
from pathlib import Path
import re
import multiprocessing
from typing import Callable, Optional
import pickle

from glob import glob
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt

from tqdm.auto import tqdm

from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, AutoModel, BertForPreTraining
import torch
import torch.nn as nn

import faiss

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
INPUT_DIR = 'chgk_baza'

def is_acceptable_quest(quest: dict) -> bool:
    if len(re.findall("\(pic: \d*.\w{1,3}\)", quest['Question'])) > 0:
        return False
    if len(re.findall("<раздатка>", quest['Question'])) > 0:
        return False
    return True

def pprint(iterable):
    for item in iterable:
        print(item)

def print_dict(data: dict):
    if data is not None:
        for key, value in data.items():
            print(f'{key}: {value}')

def parse_text(text):
    delim_regex = r'(Вопрос:\n|Ответ:\n|Комментарий:\n|Источник:\n|Автор:\n)'
    sections = re.split(delim_regex, "Вопрос:\n" + text)[1:]
    
    keys_replace_dict = {
        "Вопрос": "Question",
        "Ответ": "Answer",
        "Комментарий": "Comment",
        "Источник": "Source",
        "Автор": "Author",
    }

    keys = [keys_replace_dict[s.strip().strip(":")] for s in sections[0::2]]
    values = [s.strip().replace('\n', ' ') for s in sections[1::2]]
    return dict(zip(keys, values))

def preprocess_quest_dict(quest_dict: dict) -> Optional[dict]:
    result = dict()
    stop_set = {"---", "???"}
    if quest_dict.get('Question') is None or quest_dict.get('Answer') is None:
        return None
    if quest_dict['Question'] in stop_set or quest_dict['Answer'] in stop_set:
        return None
    if not is_acceptable_quest(quest_dict):
        return None
    
    replace_map = {"; .": ".", 
                   "  ": " ", 
                   "  ": " "}
    replace_map = dict((re.escape(k), v) for k, v in replace_map.items()) 
    pattern = re.compile("|".join(replace_map.keys()))
    result['Question'] = pattern.sub(lambda m: replace_map[re.escape(m.group(0))], quest_dict['Question'])

    replace_map = {"синонимичные ответы": "", 
                    "по смыслу": "", 
                    "и т.п.": "", 
                    "По смыслу.": "", 
                    "Зачет: ": "", 
                    "- и т.п. по смыслу": "", 
                    "Синонимичные ответы": "", 
                    "В любом написании." : "",
                    "В любом порядке.": "",
                    "В любом порядке": "",
                    "Незачет:": "",
                    "В любой орфографии.": "",
                    "Рейтинг:": "",
                    "В любом числе.": "",
                    "По упоминанию": "",
                    "По фамилии.": "",
                    "(засчитывается абсолютно точный ответ)": "",
                    ". .": ".", 
                    ".  .": ".", 
                    "; .": ".",
                    "   ": " ", 
                    "[": "",
                    "]": "",
                    '"': "",
                    ";": ",",
                    ", .": "."}
    
    replace_map = dict((re.escape(k), v) for k, v in replace_map.items()) 
    pattern = re.compile("|".join(replace_map.keys()))
    result['Answer'] = pattern.sub(lambda m: replace_map[re.escape(m.group(0))], quest_dict['Answer'])

    quest_dict['Answer'] = quest_dict['Answer'].split(' Тур: ')[0]

    if quest_dict.get('Comment') is not None:
        result['Comment'] = quest_dict['Comment']
    return result

# %%
files = sorted(list(Path(INPUT_DIR).rglob('*.txt')))

# %%
file_split_pattern = re.compile("Вопрос \d*:\n")

file = files[2]

with open(file, encoding='koi8-r') as infile:
    texts = re.split(file_split_pattern, infile.read())[1:]
    print(f"File: {file.name}, Len={len(texts)}\n")
# Answer: Морская болезнь.
# Comment: "Волны рюшей и водовороты ткани".
#
# Question: В эпизоде фильма "Полный облом" главному герою предлагают на выбор две ИХ, красного и синего цвета. Впервые ОНИ появились в 1941 году и получили название в честь двух основателей компании, фамилии которых, кстати, начиналась с одной и той же буквы. Назовите ИХ.
# Answer: Конфеты M&M's.
# Comment: Герою дали две круглые конфеты "M&M's" - по аналогии с таблетками, которые были предложены Нео в "Матрице". Фамилии основателей компании - Марс и Мьюрри.
#
# Question: Первая глава книги Николая Ващилина "Мы умирали по воле режиссеров" называется "Как погибают, оставаясь живыми, ...". Кто? Ответьте одним словом.
# Answer: Каскадеры.
#
# Question: Когда в 1980-х годах в Москве резко увеличился тариф на такси, некоторое время таксисты были в простое. Рассказывают, что, когда проходившему мимо вереницы машин Зиновию Гердту один из таксистов предложил ехать, тот, не останавливаясь, ответил: "Нет-нет. Я...". Закончите фразу двумя короткими словами.
# Answer: ... в парк.
# Comment: Обычно эту реплику можно услышать как раз от таксистов.
#
# Question: Создатели существующего в Арлингтоне музея подгоревшей еды уверены, что созерцание подгоревших пирогов, обугленных кексов или испорченной огнем пиццы должно навести посетителей на мысль о необходимости повышенного внимания к правилам ЕЕ. Назовите ЕЕ двумя словами, начинающимися на парные согласные.
# Answer: Противопожарная безопасность.
#
# Question: Согласно Википедии, ОН питается, в основном, омарами и крабами. В отличие от другого представителя того же рода, ОН не проделывает манипуляций с пищей. Назовите ЕГО.
# Answer: Енот-ракоед.  Ракоед.
# Comment: Енот-ракоед питается, в основном, ракообразными. В отличие от енота-полоскуна, он не полощет пищу перед едой.
#
# Question: Между Марселем и одним из островов Фриульского архипелага курсируют два туристических катера. Один из них называется "Александр Дюма". Назовите имя и фамилию, которые фигурируют в названии другого катера.
# Answer: Эдмон Дантес.
# Comment: Упомянутый остров - Иф.
#
# Question: Говорят, что в советские времена, когда вакцинация против бешенства состояла из 40 уколов, которые следовало колоть довольно часто, пострадавший мог взять больничный на время лечения. Говорят, что именно тогда в инструкции к вакцине и появился запрет. Ответьте как можно точнее: какой именно запрет?
# Answer: Употреблять алкоголь на протяжении всего срока вакцинации.
# Comment: Был слишком большой риск, что здоровый человек, получив больничный, уйдет в запой и не закончит курс вакцинации.
#
# Question: По сообщению юмористов, алкоголик Степан пошел в лес, чтоб посетить с ответным визитом... Кого?
# Answer: Белок.  Белочек.
#
# Question: В пародийном рассказе Олега Пелипейченко ОН, подозревая подвох в споре, всё же предупредил Гермеса, что является очень хорошим пловцом. Назовите ЕГО имя, содержащее удвоенную согласную.
# Answer: Ахилл.  Ахиллес.
# Comment: Гермес поспорил с Ахиллом, что тот не догонит черепаху. Ахилл же предположил, что Гермес хочет выставить против него морскую черепаху.
#
# Question: По утверждению Фредерика Бегбедера, этот роман нужно читать в первую очередь как роман о страстной любви. В конце романа героиня уже беременна, и ее очарование улетучилось, а герой "разочарован-разочарован". Назовите этого героя.
# Answer: Гумберт Гумберт.
# Comment: Речь идет о "Лолите" Владимира Набокова.
#
# Question: На рекламных плакатах интернет-магазина "Цитрус" содержится слоган: "Лечим ТАКУЮ зависимость". Какую - ТАКУЮ?
# Answer: Яблочную.
# Comment: "Цитрус" предлагает отказаться от продукции компании "Apple".
#
# Question: В одном из эпизодов повести Клод Изнер ВиктОр ЛегрИ, собирая разбросанные по комнате вещи жены, вспоминает персонажа небольшого произведения своего соотечественника. Назовите этого персонажа.
# Answer: Мальчик-с-пальчик.
# Comment: "Таша разбрасывала свои вещи, как Мальчик-с-пальчик - камешки в лесу". Мальчик-с-пальчик - герой одноименной сказки Шарля Перро.
#
# Question: Согласно шуточному утверждению, ИМ непонятны две вещи: как можно учиться на своих ошибках и почему говорят, что жизнь прожить - не поле перейти. Назовите ИХ.
# Answer: Саперы.
#
# Question: Согласно исследованию американских ученых, при котором тридцать пар ИХ снимали камерами без участия людей, вероятность летального исхода резко повышается в стрессовых условиях - например, при наблюдении людьми. Назовите ИХ составным словом.
# Answer: Богомолы.
# Comment: Самцы богомолов демонстрировали сложные брачные ритуалы и во всех тридцати случаях остались живыми.
#
# Question: В португальском названии ЕЕ упоминается пицца, а в польском названии - торт. Назовите ЕЕ двумя словами.
# Answer: Круговая диаграмма.
# Comment: А по-английски круговая диаграмма называется "pie chart" - "график пирога".
#
# Question: Одна из моделей "Тойоты" называется так же, как и британско-американский фильм 1986 года. Согласно украинской рекламе этой модели, с ней вы всегда будете... Где?
# Answer: На высоте.  На вершине.
# Comment: Фильм - "Горец", в оригинале - "Highlander".
#
# Question: В диалоге, написанном через несколько десятков лет после выхода известного фильма, главному герою предлагают в качестве закуски сначала черную икру, затем красную, а потом вспоминают, что в предполагаемом месте банкета на огороде растут ОНИ. Назовите ИХ.
# Answer: Баклажаны.
# Comment: Вспомните знаменитый эпизод из фильма "Иван Васильевич меняет профессию", в котором упоминаются икра черная, икра красная и заморская икра баклажанная. :-)
#
# Question: В 2009 году Шнобелевскую премию, в числе прочих, получила Елена Боднар, разработавшая бюстгальтер, который в считанные секунды превращается в противогаз - защитную маску для дыхания. В какой именно номинации была присуждена эта премия?
# Answer: В области здравоохранения.
#
# Question: Прослушайте отрывок из рецензии Фредерика Бегбедера на книгу Олдоса Хаксли "О дивный новый мир": "В 1932 году Хаксли уже предугадал всё: клонирование, детей из пробирки, тоталитаризм, материалистическую глобализацию, новый фашизм с его искусственным и обязательным счастьем, soft-идеологию. "О дивный новый мир" критикует утопии, как и...". Какое произведение, созданное шестнадцатью годами позже, упоминает далее Бегбедер?
# Answer: 1984.
#
# Question: Назовите человека, которому была посвящена статья на сайте "РИА Новости" под заголовком ""Черная пуля" для фюрера".
# Answer: Джесси Оуэнс.
# Comment: Темнокожий Джесси Оуэнс стал четырехкратным победители летней Олимпиады 1936 года в Берлине, которая, по задумке Адольфа Гитлера, должна была продемонстрировать превосходство белой расы.
#
# Question: В одном из знаменитых зарубежных мультфильмов 1960-х годов говорится, что одна минута - это очень много, а ЭТО - 33 миллиона 661 тысяча 440 минут. Назовите ЭТО.
# Answer: 64 года.
# Comment: Речь идее о песне "When I'm 64" и ее визуальном сопровождении в мультфильме "Yellow submarine".
# Answer: Копыта Пегаса.
# Comment: По легенде, Пегас мог копытом выбивать источники.
#
# Question: По словам пятикратного участника матча звезд НБА Криса Уэббера, команда из этого города стала самой разочаровывающей командой текущего сезона. Однако, высказывая свое мнение, Уэббер не использовал фразу, впервые прозвучавшую в фильме 1964 года "Робинзон Крузо на Марсе". Какой фильм сделал эту фразу знаменитой?
# Answer: Аполлон-13.
# Comment: Упомянутый в вопросе город - Хьюстон, фраза - "Хьюстон, у нас проблема".
#
# Question: Наполеон Бонапарт накануне смерти говорил: "Я в своей жизни носил три короны: золотую - во Франции, "железную" - в Италии, а на острове Святой Елены - ...". Какую?
# Answer: Терновую.
# Comment: Т.е. терновый венец мученика; "железной" именовали старинную корону лангобардов, правивших в Италии в VI-VIII веках, ею Наполеон был увенчан как король Италии.
#
# Question: По данным журнала "GEO", на свалках Цюриха ежегодно добывается 10 килограммов ЕГО. По данным Википедии, в 2014 году мировым лидером по ЕГО добыче был Китай - 450 тонн (США и Канада, соответственно, на четвертом и пятом местах). Назовите ЕГО.
# Answer: Золото.
# Comment: Рачительные швейцарцы добывают из отходов золото и не только. А США и Канада исторически связаны со знаменитой "золотой лихорадкой".

# %%
texts = []
for file in tqdm(files):
    with open(file, encoding='koi8-r') as infile:
        texts = texts + re.split(file_split_pattern, infile.read())[1:]

quest_list = []
for text in tqdm(texts):
    quest = preprocess_quest_dict(parse_text(text))
    if quest is not None:
        quest_list.append(quest)
# Out:
#   0%|          | 0/4363 [00:00<?, ?it/s]
#   0%|          | 0/336036 [00:00<?, ?it/s]

# %%
#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask

def embed_bert_cls(text, model, tokenizer, max_len):
    encoded_input = tokenizer(text, padding=True, truncation=True, max_length=max_len, return_tensors='pt').to(DEVICE)
    with torch.no_grad():
        model_output = model(**encoded_input)
    embeddings = model_output.last_hidden_state[:, 0, :]
    embeddings = torch.nn.functional.normalize(embeddings)
    return embeddings.cpu().numpy()

def embed_bert_mean(text, model, tokenizer, max_len):
    encoded_input = tokenizer(text, padding=True, truncation=True, max_length=max_len, return_tensors='pt').to(DEVICE)
    with torch.no_grad():
        model_output = model(**encoded_input)
    embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
    embeddings = torch.nn.functional.normalize(embeddings)
    return embeddings.cpu().numpy()

def calc_texts_dist_cls(text1, text2, model, tokenizer, max_len) -> float:
    emb1 = embed_bert_cls(text1, model, tokenizer, max_len)
    emb2 = embed_bert_cls(text2, model, tokenizer, max_len)
    return ((emb1 - emb2)**2).sum()


def calc_embs(train_loader: DataLoader, model: nn.Module, tokenizer: AutoTokenizer, emb_function: Callable, max_len: int):
    embs = []
    for batch in tqdm(train_loader):
        # print(batch[1][0])
        question_batch, answer_batch = batch
        q_embs = emb_function(question_batch, model, tokenizer, max_len=max_len)
        a_embs = emb_function(answer_batch, model, tokenizer, max_len=max_len)
        embs.append(q_embs*0.5 + a_embs*0.5)
    return np.concatenate(embs)

# %%
# MODEL = "cointegrated/rubert-tiny2"
MODEL = "sberbank-ai/sbert_large_mt_nlu_ru"
EMB_FUNCTION = embed_bert_mean
MAX_LEN = 512

#Load AutoModel from huggingface model repository
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModel.from_pretrained(MODEL).to(DEVICE)

# %%
# =========================================================================================
# Dataset
# =========================================================================================
class QuestNN_Dataset(Dataset):
    def __init__(self, quest_list: list):
        self.data = [self.quest_to_str(x) for x in quest_list]

    @classmethod
    def quest_to_str(cls, quest_dict: dict) -> str:
        # result = quest_dict['Question'] + "Ответ: " + quest_dict.get('Answer')
        # if quest_dict.get('Ответ') is not None:
        #     result += "Ответ: " + quest_dict.get('Ответ')
        # if quest_dict.get('Комментарий') is not None:
        #     result += quest_dict.get('Комментарий')
        return (quest_dict['Question'], 
                "Ответ: " + quest_dict.get('Answer'))

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, item):
        return self.data[item]
    
os.environ["TOKENIZERS_PARALLELISM"] = "false"

train_loader = DataLoader(
    QuestNN_Dataset(quest_list), 
    batch_size = 256, 
    shuffle = False, 
    num_workers = 3, 
    pin_memory = True, 
    drop_last = False
)

# %%
embs = calc_embs(train_loader, model, tokenizer, EMB_FUNCTION, max_len=MAX_LEN)
# embs = calc_embs(train_loader, model, tokenizer, embed_bert_mean, max_len=MAX_LEN)

np.save(os.path.join(INPUT_DIR, 'embs_ruberttiny2.npy'), embs)
# Out:
#   0%|          | 0/1250 [00:00<?, ?it/s]

# %%
embs = np.load(os.path.join(INPUT_DIR, 'embs.npy'))
print(embs.shape)
# (319759, 312)
# Out:
# (319759, 1024)

# %%
#Sentences we want sentence embeddings for
sentences = np.array([QuestNN_Dataset.quest_to_str(x) for x in quest_list[10:12]])
print(sentences)

#Perform pooling. In this case, mean pooling
sentence_embeddings = EMB_FUNCTION(list(sentences[:, 0]), model, tokenizer, max_len=MAX_LEN)*0.5 + EMB_FUNCTION(list(sentences[:, 1]), model, tokenizer, max_len=MAX_LEN)*0.5
sentence_embeddings = embed_bert_mean(list(sentences[:, 0]), model, tokenizer, max_len=MAX_LEN)*0.5 + embed_bert_mean(list(sentences[:, 1]), model, tokenizer, max_len=MAX_LEN)*0.5

assert embs.shape[1] == sentence_embeddings.shape[1]
print((sentence_embeddings[0] * sentence_embeddings[1]).sum())
print((embs[10] * embs[11]).sum())
# Out:
# [['В одной из серий "Доктора Кто", действие которой разворачивается в 1926 году, ОНА на вопрос о своем выборе отвечает так: бельгийцы пекут вкусные булочки. Другая "ОНА" появилась в 1988 году. Назовите ЕЕ.'
#   'Ответ: Агата Кристи.']
#  ['Согласно юмористическому сообщению, неизвестная русская женщина парализовала проходившие в графстве Эссекс соревнования... По какому спорту?'
#   'Ответ: По конному спорту.']]
# 0.40359873
# 0.40359876

# %%
res = faiss.StandardGpuResources()
nlist = 5000
index = faiss.index_cpu_to_gpu(res, 0, faiss.IndexFlatL2(embs.shape[1]))
quantizer = faiss.IndexFlatL2(embs.shape[1])
# index = faiss.IndexIVFFlat(quantizer, embs.shape[1], nlist)
# gpu_index = faiss.index_cpu_to_gpu(res, 0, index)
if not index.is_trained:
    index.train(embs)
index.add(embs)                  
# faiss.write_index(index, os.path.join(INPUT_DIR, 'faiss.index'))

# %%
print(faiss.MatrixStats(embs).comments)
# index = faiss.read_index(os.path.join(INPUT_DIR, 'faiss.index'))
k = 15
distances, indices = index.search(embs, k) # sanity check
print(indices[:, 1:])
print(distances[:, 1:])
# Out:
# analyzing 319759 vectors of size 1024
# no NaN or Infs in data
# 318598 vectors are distinct (99.64%)
# vector 210192 has 3 copies
# range of L2 norms=[0.683066, 0.984089] (0 null vectors)
# matrix contains 0.00 % 0 entries
# no constant dimensions
# no dimension has a too large mean
# stddevs per dimension are in [0.00707198 0.0475416]
#
# [[140816 181004 314568 ... 200632 136512  52933]
#  [299021  74863 191326 ... 257580 228281 104425]
#  [220792 117175 117155 ... 237793 252345  73565]
#  ...
#  [122475   4844 183200 ... 256889 207840 203193]
#  [201792 223845 151514 ... 294441 200230 260271]
#  [183390  91982 255115 ... 146911 230299 185381]]
# [[0.21680605 0.23153412 0.24172926 ... 0.2721287  0.27239072 0.2754647 ]
#  [0.14605105 0.15370452 0.15524256 ... 0.1721797  0.17217982 0.17256498]
#  [0.23815942 0.24166662 0.24699628 ... 0.2724374  0.27262688 0.2733537 ]
#  ...
#  [0.195647   0.20073068 0.20313627 ... 0.2142762  0.21428531 0.21459097]
#  [0.19521976 0.19617343 0.20455182 ... 0.2204575  0.2213288  0.22217023]
#  [0.1793009  0.20139271 0.21611679 ... 0.23861039 0.23963118 0.23982537]]

# %%
quest_dict = dict()
i = 0

for quest in quest_list:
    quest_dict[i] = (quest, indices[:, 1:][i], distances[:, 1:][i])
    i += 1
    
print(len(quest_dict))

threshold = 0.12
for i in tqdm(range(len(quest_dict))):
    if quest_dict.get(i) is not None:
        quest, q_indices, q_distances = quest_dict[i]
        for ind, dist in zip(q_indices, q_distances):
            if quest_dict.get(ind) is not None:
                if dist < threshold:
                    # print(quest_dict[i], "\n", quest_dict[ind], "\n")
                    quest_dict.pop(ind, None)

print(len(quest_dict))
# Out:
# 319759
#   0%|          | 0/319759 [00:00<?, ?it/s]
# 291735

# %%
threshold = 0.1203
for i in tqdm(range(len(quest_dict))):
    if quest_dict.get(i) is not None:
        quest, q_indices, q_distances = quest_dict[i]
        for ind, dist in zip(q_indices, q_distances):
            if quest_dict.get(ind) is not None:
                if dist < threshold:
                    print(quest_dict[i][0], "\n", quest_dict[ind][0], "\n")
                    quest_dict.pop(ind, None)
# Out:
#   0%|          | 0/291735 [00:00<?, ?it/s]
# {'Question': 'ЕМУ приписывают фразу: "Главное, чтобы тебя окружали хорошие люди". По легенде, в начале 1943 года Гитлер лично положил на ЕГО гроб жезл с бриллиантами. Назовите ЕГО.', 'Answer': 'Фридрих Паулюс.'}
#  {'Question': 'Во время воздушного налета ОН потерял глаз, правую руку и два пальца левой руки. В 1943 году ОН писал жене: "Настанет время, когда я спасу Германию". Назовите ЕГО.', 'Answer': 'Клаус Шенк фон Штауффенберг.'}
#
# {'Question': 'Какое существо Плиний Старший определил так: "змея с белым пятном на голове, похожим на корону или диадему"?', 'Answer': 'василиск.'}
#  {'Question': 'Согласно Лукану, из крови Медузы Горгоны появился царь Ливийских змей. Под каким названием он фигурирует у Плиния Старшего?', 'Answer': 'Василиск.', 'Comment': '"Царек" по-гречески. Подобно Медузе Горгоне, василиск обладал смертоносным взглядом.'}
#
#  {'Question': 'Великий английский философ Томас Гоббс велел выбить на своем могильном камне им же самим сочиненную эпитафию: "Здесь лежит истинно (два слова пропущено)". Эти же два слова фигурируют в заглавии романа, вышедшего в свет 26 июня 1997 года. Назовите имя и фамилию, которые можно встретить в заглавии того же романа.', 'Answer': 'Гарри Поттер.', 'Comment': 'Пропущенные слова - "философский камень".'}
#
# {'Question': 'В журнале "Esquire" сказано, что это произведение - аллегория мужской уверенности и спокойствия и неустойчивого мира женщины. Назовите это произведение.', 'Answer': 'Девочка на шаре.'}
#  {'Question': 'В номере журнала "Esquire" за сентябрь 2006 г. приводятся комментарии посетителей музеев живописи. По поводу одной из известнейших картин начала 20 века некая дама сказала, что полотно символизирует мужскую уверенность и спокойствие и неустойчивый мир женщины. Назовите эту картину.', 'Answer': 'Девочка на шаре.'}
#
# {'Question': 'Самое крупное наводнение в Северной Америке случилось в 1811 году в долине Миссисипи. Колокола звонили аж до сАмого Массачусетса. В этом вопросе мы заменили одно слово. Какое?', 'Answer': 'Землетрясение.', 'Comment': 'Колокола звонили без посторонней помощи.'}
#  {'Question': 'Как ни странно, это случалось и в Лондоне. Когда это произошло во второй половине XVI века, очевидцы отмечали, что большие колокола церквей звонили сами, словно город предупреждал об опасности. Назовите это.', 'Answer': 'Землетрясение.'}
#
# {'Question': 'Опубликованная в газете "Команда" статья "На Париже в Лондон" была посвящена перспективам Украины в одном из олимпийских видов спорта. Назовите этот вид спорта.', 'Answer': 'Конный спорт.', 'Comment': 'Единственная представительница Украины на предстоящей Лондонской Олимпиаде в выездке Светлана Киселева выступает на коне по кличке Париж.'}
#  {'Question': 'Первый - это чисто мужской вид безуключинных олимпийских гонок. Второй - тоже олимпийский вид спорта, входящий в состав некой дисциплины, причем один из его атрибутов дал название всей этой дисциплине. В 1996 году по предложению Крылова была зарегистрирована международная ассоциация нового, объединенного, вида спорта с аббревиатурой FIIB. Хотя, конечно, было бы логичнее, если бы его изобретателем стал представитель другого континента. Назовите этот вид спорта.', 'Answer': 'Индейский биатлон.', 'Comment': 'Гребля на каноэ и стрельба из лука. Слово "стрела" дало название стрельбе.'}
#
# {'Question': 'Создатели одной из версий фильма 1934 года поступили аналогично своему более известному коллеге. Назовите англоязычный роман, экранизацией которого является этот фильм.', 'Answer': 'Алая буква.', 'Comment': 'Подобно Эйзенштейну, букву "A" на груди Эстер Принн из романа НатаниЭля ГОторна "Алая буква" создатели этой версии раскрасили в красный цвет.'}
#  {'Question': 'Комедия "Отличница легкого поведения" в оригинале называется "Easy A" [Изи эй], что означает и легко доставшуюся пятерку, и легко доступную девушку. Назовите произведение 1850 года, комическим переосмыслением которого является этот фильм.', 'Answer': 'Алая буква.', 'Comment': 'В произведении Натаниэля ГОторна, рассказывающем о женщине, загубившей свою репутацию, буква "A" [эй] означает "адюльтер".'}
#
# {'Question': 'Назовите фамилию отечественного писателя, которому Евгений Лукин посоветовал написать роман "Шентиментальное путешествие".', 'Answer': 'Борис Штерн.', 'Comment': 'Лоуренс Стерн написал "Сентиментальное путешествие", а Штерну, по мнению Лукина, полагалось написать "Шентиментальное путешествие".'}
#  {'Question': 'Назовите автора известного романа, который, по словам Аркадия Аверченко, вышел на русском языке под названием "Наши дамы из Парижа".', 'Answer': 'Виктор Гюго.', 'Comment': 'Имеется в виду роман "Notre Dame de Paris".'}
#  {'Question': 'Узнав о псевдонаучном "открытии" некоего Анатолия Золотухина, автор вопроса сочинил ироническое двустишие, во второй строке которого упоминались Львов, Запорожье, Херсон, Киев, Харьков, Одесса, Полтава. Какому человеку было посвящено это "открытие"?', 'Answer': 'Гомер.', 'Comment': 'Золотухин утверждает, что Гомер был украинцем. Полный текст бескрылки: "Семь городов, пререкаясь, зовутся отчизной Гомера: / Львов, Запорожье, Херсон, Киев, Харьков, Одесса, Полтава". Первая строка взята из известной греческой эпиграммы.'}
#
# {'Question': 'Многие считают, что в современных шахматах всё бОльшую роль играет хорошая память, а не сила мысли. Тем не менее, исландский шахматный клуб назван в честь ПЕРВОГО, а не в честь ВТОРОГО. Назовите ПЕРВОГО и ВТОРОГО.', 'Answer': 'Хугин, Мунин.  ', 'Comment': 'В скандинавской мифологии у бога Одина было два ворона, Хугин ("мысль") и Мунин ("память"). Исландский шахматный клуб носит название "Хугин".'}
#  {'Question': 'Многие жалуются на то, что в современных шахматах всё больше решает хорошая память. А вот название одного исландского шахматного клуба не только является данью древней традиции, но и намекает на то, что его игроки полагаются не на память, а на мышление. Воспроизведите это название.', 'Answer': 'Хугин.', 'Comment': 'В скандинавской мифологии у бога Одина было два ворона - Хугинн ("мысль") и Мунинн ("память"). Неудивительно, что исландский шахматный клуб носит название "Хугин".'}
#
# {'Question': 'Менее чем за два месяца до конца Великой Отечественной войны Льва Копелева сместили с занимаемой должности. Близкие люди написали на него доносы, нанеся ему тем самым множество психологических ударов. Глава книги Копелева, повествующая об этом, называется "ОНИ". Назовите ИХ двумя словами.', 'Answer': 'Мартовские иды.', 'Comment': 'Дело было в середине марта. Как и Цезарю, Копелеву нанесли множество ударов.'}
#  {'Question': 'В начале весны 1801 года Павел I пришел к выводу, что против него готовится заговор, и заговорщикам пришлось поменять планы. Повествуя о первоначальном замысле убийства, Википедия упоминает ИХ. Назовите ИХ двумя словами.', 'Answer': 'Мартовские иды.', 'Comment': 'Заговорщики хотели символично уподобить свое деяние убийству Цезаря. Мартовские иды соответствуют дню 15 марта, однако заговорщикам пришлось поторопиться, и в итоге убийство произошло в ночь с 11 на 12 марта.'}
#
# {'Question': 'Герой романа Бегбедера вспоминает строки Мишеля Уэльбека, в которых тот утверждает, что ОНИ сверкают никелем и возносят нас на Голгофу. Назовите фамилию человека, который изобрел систему задержки для НИХ.', 'Answer': 'Отис.', 'Comment': 'У Уэльбека: "Сверкая никелем, набитые кабины / Возносят на Голгофу нас, к кресту. / Повсюду секретарши-магдалины / Наводят торопливо красоту".'}
#  {'Question': 'В конце XIX века Уллис Гриффони написал роман, в котором американец тратит на осуществление своей затеи всего месяц. В конце книги от огорчения умирает некий пожилой англичанин. Назовите его фамилию.', 'Answer': 'Фогг.', 'Comment': 'Роман назывался "Вокруг света за тридцать дней". Узнав о том, что его рекорд побит, Фогг скончался от огорчения.'}

# %%
quest_clean_list = []
for _, quest in quest_dict.items():
    quest_clean_list.append(quest[0])

print(len(quest_clean_list))
with open(os.path.join(INPUT_DIR, 'quest_clean_list.pkl'), 'wb') as f:
    pickle.dump(quest_clean_list, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 291616

# %%
with open(os.path.join(INPUT_DIR, 'quest_clean_list.pkl'), 'rb') as f:
    quest_clean_list = pickle.load(f)
